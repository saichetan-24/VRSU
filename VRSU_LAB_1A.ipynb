# %% [markdown]
# Week 1

# %%
import cv2
import matplotlib.pyplot as plt

# Load image
img = cv2.imread("/content/vertical-closeup-grayscale-shot-fluffy-domestic-cat-sitting-floor_181624-35037.avif")

# Convert to grayscale (IMPORTANT)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply histogram equalization
heimg = cv2.equalizeHist(img_gray)

# Plot results
plt.figure(figsize=(12,5))

plt.subplot(1,3,1)
plt.title("Original Image")
plt.imshow(img_gray, cmap="gray")
plt.axis("off")

plt.subplot(1,3,2)
plt.title("Histogram Equalized")
plt.imshow(heimg, cmap="gray")
plt.axis("off")

plt.subplot(1,3,3)
plt.title("Histogram (Equalized)")
plt.hist(heimg.ravel(), 256, [0,256])
plt.show()
# Out:
# /tmp/ipython-input-586758458.py:28: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(heimg.ravel(), 256, [0,256])

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import matplotlib.pyplot as plt

img=cv2.imread("/content/vertical-closeup-grayscale-shot-fluffy-domestic-cat-si tting-floor_181624-35037.avif",0)
heimg=cv2.equalizeHist(img)
plt.figure(figsize=(12,5))

plt.subplot(1,3,1)
plt.title("Original Image")
plt.imshow(img,cmap="gray")
# plt.axis("Off")

plt.subplot(1,3,2)
plt.title("Histogram Equalization")
plt.imshow(heimg,cmap="gray")
plt.axis("Off")

plt.subplot(1,3,3)
plt.title("Histogram(Equlaized)")
plt.hist(heimg.ravel(),256,[0,256])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /tmp/ipython-input-728368455.py:23: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(heimg.ravel(),256,[0,256])
